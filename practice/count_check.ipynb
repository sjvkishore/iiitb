# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('15april.csv')

df2 = pd.read_csv('MicroserviceAvro22888.csv')

# %%
df1.shape
# Out:
# (22933, 15)

# %%
df2.shape
# Out:
# (22888, 15)

# %%
diff = pd.concat([df1, df2]).loc[df1.index.symmetric_difference(df2.index)]

# %%
diff.shape
# Out:
# (45, 15)

# %%
diff
# Out:
#        RecordID Tenant Code               Name       Type  \
# 22888    306252          XG    BNDRY_CURR_ASSC     string
# 22889    306253          XG    BNDRY_CURR_ASSC     string
# 22890    306254          XG     CURR_USAGE_TYP        int
# 22891    306255          XG     CURR_USAGE_TYP     string
# 22892    306256          XG     CURR_USAGE_TYP     string
# 22893    306257          XG     CURR_USAGE_TYP     string
# 22894    306258          XG     CURR_USAGE_TYP     string
# 22895    306259          XG   BNDRY_CURR_USAGE        int
# 22896    306260          XG   BNDRY_CURR_USAGE        int
# 22897    306261          XG   BNDRY_CURR_USAGE     string
# 22898    306262          XG   BNDRY_CURR_USAGE     string
# 22899    306263          XG        CURR_SYMBOL     string
# 22900    306264          XG        CURR_SYMBOL     string
# 22901    306265          XG        CURR_SYMBOL     string
# 22902    306266          XG    CURR_SYMBOL_TYP     string
# ...
